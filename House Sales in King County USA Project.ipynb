# %% [raw]
# # DATA DESCRIPTION:
# The dataset consists of house prices from King County an area in the US State of Washington, this data also covers Seattle. The dataset is a portion of a larger dataset that consisted of 21 variables and 21613 observations.
#
# ATTRIBUTES:
# id= It is the unique numeric number assigned to each house being sold.
# date= It is the date on which the house was sold out.
# price= It is the price of house which we have to predict so this is our target variable and aprat from It are our features.
# bedrooms= It determines number of bedrooms in a house.
# bathrooms= It determines number of bathrooms in a bedroom of a house.
# sqft_living= It is the measurement variable which determines the measurement of house in square foot.
# sqft_lot= It is also the measurement variable which determines square foot of the lot.
# floors= It determines total floors means levels of house.
# waterfront= This feature determines whether a house has a view to waterfront 0 means no 1 means yes.
# view= It determines the number of viewings the property received.
# condition= It determines the overall condition of a house on a scale of 1 to 5.
# grade= It determines the overall grade given to the housing unit, based on King County grading system on a scale of 1 to 11 sqft_above= It determines square footage of house apart from basement.
# sqft_basement= It determines square footage of the basement of the house.
# yr_built= It detrmines the date of building of the house.
# yr_renovated= It detrmines year of renovation of house.
# zipcode= It determines the zipcode of the location of the house.
# lat= It determines the latitude of the location of the house.
# long= It determines the longitude of the location of the house.
# sqft_living15= Living room area in 2015(implies-- some renovations)
# sqft_lot15= lotSize area in 2015(implies-- some renovations)

# %%
#import the library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset
data=pd.read_csv('kc_house_data.csv')

# %% [raw]
# a. What are the number of rows; no. & types of variables (continuous, categorical etc.)

# %%
# a)
print(data.shape)
print('No of Rows: ',data.shape[0])
print('No of Columns: ',data.shape[1])
# Out:
# (21613, 21)
# No of Rows:  21613
# No of Columns:  21

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.select_dtypes(include=np.number).columns
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.select_dtypes(include='object').columns
# Out:
# Index(['date'], dtype='object')

# %% [raw]
# b. Calculate five point summary for numerical variables

# %%
data.describe(include=np.number).T
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %% [raw]
# c. Summarize observations for categorical variables – no. of categories, % observations in each category

# %%
cat_cols=['bedrooms','bathrooms','floors','waterfront','view','condition','grade']

# %%
for i in cat_cols:
    cat_per=data[i].value_counts(normalize=True)*100
    print('percentage of observation in:',i)
    print(cat_per)
# Out:
# percentage of observation in: bedrooms
# bedrooms
# 3     45.454125
# 4     31.841947
# 2     12.770092
# 5      7.407579
# 6      1.258502
# 1      0.920742
# 7      0.175820
# 0      0.060149
# 8      0.060149
# 9      0.027761
# 10     0.013881
# 11     0.004627
# 33     0.004627
# Name: proportion, dtype: float64
# percentage of observation in: bathrooms
# bathrooms
# 2.50    24.892426
# 1.00    17.822607
# 1.75    14.102623
# 2.25     9.471152
# 2.00     8.929811
# 1.50     6.690418
# 2.75     5.482811
# 3.00     3.484014
# 3.50     3.382224
# 3.25     2.725212
# 3.75     0.717161
# 4.00     0.629251
# 4.50     0.462684
# 4.25     0.365521
# 0.75     0.333133
# 4.75     0.106417
# 5.00     0.097164
# 5.25     0.060149
# 0.00     0.046268
# 5.50     0.046268
# 1.25     0.041642
# 6.00     0.027761
# 0.50     0.018507
# 5.75     0.018507
# 6.75     0.009254
# 8.00     0.009254
# 6.25     0.009254
# 6.50     0.009254
# 7.50     0.004627
# 7.75     0.004627
# ...

# %% [raw]
# a. Do variables have missing/null values?

# %%
# a)
data.isnull().sum()
# No variables do not have any missing or null values
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [raw]
# b. Do variables have outliers?

# %%
# b)
plt.figure(figsize=(9,8))
sns.distplot(data['price'],color='b',bins=20,hist_kws={'alpha':0.4})
# There are some outliers in the data as we can see that it is right skewed target variable and not a normally distributed one.
# Out:
# C:\Users\DIKSHA YADAV\AppData\Local\Temp\ipykernel_11808\1531798383.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['price'],color='b',bins=20,hist_kws={'alpha':0.4})
# <Axes: xlabel='price', ylabel='Density'>

# %%
data.plot(kind='box',figsize=(20,10))
# Out:
# <Axes: >

# %%
data['price'].plot(kind='box',figsize=(5,5))
# Out:
# <Axes: >

# %% [raw]
# a. Plot correlation plots. Which are the variables most correlated with Target? Which independent variables are correlated among themselves? Do you want to exclude some variables from the model based on this analysis? What other actions will you take?

# %%
plt.figure(figsize=(25,10))
sns.heatmap(data.corr(numeric_only=True), annot=True, vmax=1, vmin=-1, cmap='rainbow')
plt.show()

# %% [raw]
# a. Are both train and test representative of the overall data? How would you ascertain this statistically?

# %%
from sklearn.model_selection import train_test_split

# %%
X=data.drop(['price'],axis=1)
y=data['price']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size=0.2,random_state=74)

# %%
desc=X.describe()
desc
# Out:
#                  id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   4.580302e+09      3.370842      2.114757   2079.899736  1.510697e+04
# std    2.876566e+09      0.930062      0.770163    918.440897  4.142051e+04
# min    1.000102e+06      0.000000      0.000000    290.000000  5.200000e+02
# 25%    2.123049e+09      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    3.904930e+09      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    7.308900e+09      4.000000      2.500000   2550.000000  1.068800e+04
# max    9.900000e+09     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
L1=list(desc.loc['mean'])
L1
# Out:
# [4580301520.864988,
#  3.37084162309721,
#  2.1147573219821405,
#  2079.8997362698374,
#  15106.967565816869,
#  1.4943089807060566,
#  0.007541757275713691,
#  0.23430342849211122,
#  3.4094295100171195,
#  7.656873178179799,
#  1788.3906907879516,
#  291.5090454818859,
#  1971.0051357978994,
#  84.40225790033776,
#  98077.93980474715,
#  47.56005251931708,
#  -122.21389640494147,
#  1986.552491556008,
#  12768.455651691113]

# %%
desc2=y.describe()
desc2
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %% [raw]
# We are splitiing the data ito training and testing data.the training set contains a known output and the model learns on the data to become a generalized model . We have a test data (ytest) in order to test our model prediction on ths test data.
#
# We are mentioning the random state so that a new random value is not generated and each time different set of values pass in to the train and test datasets. When we use a particular value for random state then same data points will pass in to train and test and output will be same.
#
# Looking at mean of population, train and test data also we can statistically say that the train and test are representative of the overall data.

# %% [raw]
# Fit a base model. Please write your key observations

# %%
import statsmodels.formula.api as sfa

# %%
model=sfa.ols('price~bedrooms+bathrooms+sqft_living+view+grade+sqft_above+sqft_basement+lat',data).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.640
# Model:                            OLS   Adj. R-squared:                  0.640
# Method:                 Least Squares   F-statistic:                     5485.
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):               0.00
# Time:                        14:19:41   Log-Likelihood:            -2.9657e+05
# No. Observations:               21613   AIC:                         5.931e+05
# Df Residuals:                   21605   BIC:                         5.932e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
model=sfa.ols('price~sqft_living',data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.493
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                 2.100e+04
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):               0.00
# Time:                        14:21:16   Log-Likelihood:            -3.0027e+05
# No. Observations:               21613   AIC:                         6.005e+05
# Df Residuals:                   21611   BIC:                         6.006e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -4.358e+04   4402.690     -9.899      0.000   -5.22e+04    -3.5e+04
# ...

# %%
import statsmodels.api as sma 

X_const=sma.add_constant(X)

# %% [raw]
# 1) Summarize the overall fit of the model and list down the measures to prove that it is a good model
# Initially we built the model with all features without any scaling and feature engineering but the results are not fruitful
#
# After that we tried multiple techniques to built the model only on the features which are statistically significant still there no major improvement in the model.
#
# RMSE score of ridge model with feature engineering - 0.851
#
# RMSE score of lasso model with features engineering - 1.00
#
# 2) Write down a business interpretation/explanation of the model – which variables are affecting the target the most and explain the relationship. Feel free to use charts or graphs to explain.
# from the heatmap itself we can clearly see that there are very few variables with high positive correlation with respect to independent variable,the highest correlation was sqft_living with 0.69.
#
# from the Statistical analysis, the variables affecting the target most are
#
# bedrooms
#
# bathrooms
#
# sqft_living
#
# sqft_above
#
# sqft_basement
#
# 3) What changes from the base model had the most affect on model performance
# Feature Scaling and regularization has the most affect on model performance
#
# 4) What are the key risks to your results and interpretation
# The key risks is that very few of the independent variables have good correlation with dependent variable.
#
# There is a presence of multi-collinearity in the data it effects the model performance .
